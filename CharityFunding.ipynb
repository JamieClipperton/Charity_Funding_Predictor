# %% [markdown]
# # Step 1: Preprocessing the Data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-78849a18-c418-472f-8f9a-c8786a7b40f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78849a18-c418-472f-8f9a-c8786a7b40f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving charity_data.csv to charity_data.csv

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# TARGET VARIABLE : "IS_SUCCESSFUL"
# FEATURES : "INCOME_AMT" AND "ASK_AMT"

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN','NAME'])
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_bins = application_df['APPLICATION_TYPE'].value_counts()
app_bins
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = app_bins.loc[app_bins<500].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_bins = application_df['CLASSIFICATION'].value_counts()
class_bins
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_bins.loc[class_bins>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = class_bins.loc[class_bins<100].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 50 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop(columns=["IS_SUCCESSFUL"],axis=1)
y = application_df["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=39)

# %%
X
# Out:
#        STATUS   ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0           1      5000                       0                     1
# 1           1    108590                       0                     0
# 2           1      5000                       0                     0
# 3           1      6692                       0                     0
# 4           1    142590                       0                     0
# ...       ...       ...                     ...                   ...
# 34294       1      5000                       0                     0
# 34295       1      5000                       0                     0
# 34296       1      5000                       0                     0
# 34297       1      5000                       0                     0
# 34298       1  36500179                       0                     0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# 1                         0                    1                    0
# 2                         0                    0                    0
# 3                         0                    1                    0
# 4                         0                    1                    0
# ...                     ...                  ...                  ...
# 34294                     0                    0                    1
# 34295                     0                    0                    1
# 34296                     0                    1                    0
# 34297                     0                    0                    0
# 34298                     0                    1                    0
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        1                    0                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    0                    0                    0  ...
# 34295                    0                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    1                    0                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 49 columns]

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 34294    0
# 34295    0
# 34296    0
# 34297    1
# 34298    0
# Name: IS_SUCCESSFUL, Length: 34299, dtype: int64

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
print(X_train_scaled.shape)
print(X_test_scaled.shape)
# Out:
# (25724, 49)
# (8575, 49)

# %% [markdown]
# # Step 2: Compile, Train and Evaluate the Model

# %% [markdown]
# # model 1:attempt 1

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=9, input_dim=len(X_train.columns), activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=25, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 450
#
#  dense_1 (Dense)             (None, 25)                250
#
#  dense_2 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 726
# Trainable params: 726
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5932 - accuracy: 0.7016
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5575 - accuracy: 0.7266
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5536 - accuracy: 0.7274
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5518 - accuracy: 0.7281
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7285
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7299
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5488 - accuracy: 0.7302
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7314
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7312
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7314
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7324
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5455 - accuracy: 0.7327
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7322
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7327
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7322
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7332
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7322
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5439 - accuracy: 0.7327
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7329
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7335
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5429 - accuracy: 0.7326
# Epoch 22/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7346
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7341
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7339
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7345
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5425 - accuracy: 0.7335
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7346
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7353
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7327
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7342
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.7342
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7337
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.7336
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.7350
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7352
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7339
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7352
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7349
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7356
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7352
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7351
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7358
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7347
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5409 - accuracy: 0.7358
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5405 - accuracy: 0.7365
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5400 - accuracy: 0.7349
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7351
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5401 - accuracy: 0.7358
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7357
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7358
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7355
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7355
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5400 - accuracy: 0.7357
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5401 - accuracy: 0.7363
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7366
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7352
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7363
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7356
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7368
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7354
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7358
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7367
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7366
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7369
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7354
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7369
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7362
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7364
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7361
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7361
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7370
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7361
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5387 - accuracy: 0.7372
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7361
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7349
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7376
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7378
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7355
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7363
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7360
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7369
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5387 - accuracy: 0.7364
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7361
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7353
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7364
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7365
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7371
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7365
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7371
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7368
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7372
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7376
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7353
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7383
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7374
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7367
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7372
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7370
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7369
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7365

# %%
# Evaluate the model using the test data 
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test,verbose=2)
print(f"Loss; {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5546 - accuracy: 0.7240 - 463ms/epoch - 2ms/step
# Loss; 0.5546121597290039, Accuracy: 0.7239649891853333

# %%
# Export model to HDF5 file
from google.colab import files

nn.save("AlphabetSoupCharity.h5")
files.download("AlphabetSoupCharity.h5")

# %% [markdown]
# # Model 1: attempt 2

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, input_dim=len(X_train.columns), activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=60, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=40, activation = 'relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                4000
#
#  dense_1 (Dense)             (None, 60)                4860
#
#  dense_2 (Dense)             (None, 40)                2440
#
#  dense_3 (Dense)             (None, 1)                 41
#
# =================================================================
# Total params: 11,341
# Trainable params: 11,341
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5656 - accuracy: 0.7229
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.7303
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7311
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5477 - accuracy: 0.7328
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7331
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7332
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7356
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7347
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7337
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7342
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7365
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5409 - accuracy: 0.7369
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5409 - accuracy: 0.7373
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7378
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7368
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7376
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7369
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7377
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7372
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7388
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7377
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7383
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5372 - accuracy: 0.7387
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7394
# Epoch 25/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5362 - accuracy: 0.7384
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7393
# Epoch 27/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5360 - accuracy: 0.7386
# Epoch 28/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5360 - accuracy: 0.7388
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7397
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7395
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7387
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7391
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7391
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7395
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7396
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7406
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7402
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7389
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7394
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7396
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7404
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7402
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7405
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7404
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7410
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7409
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7411
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7410
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7408
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7410
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7404
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7404
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7411
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7414
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7416
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7410
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7409
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7422
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7414
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7417
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7413
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7411
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7402
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7417
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7413
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7406
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7411
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5300 - accuracy: 0.7419
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7408
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7411
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5297 - accuracy: 0.7417
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7411
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5300 - accuracy: 0.7418
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7421
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5294 - accuracy: 0.7416
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5293 - accuracy: 0.7417
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5295 - accuracy: 0.7419
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5293 - accuracy: 0.7422
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5296 - accuracy: 0.7413
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7417
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5291 - accuracy: 0.7413
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5288 - accuracy: 0.7421
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5295 - accuracy: 0.7414
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5291 - accuracy: 0.7425
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5292 - accuracy: 0.7417
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5288 - accuracy: 0.7422
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5290 - accuracy: 0.7418
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5287 - accuracy: 0.7418
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5287 - accuracy: 0.7416
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5294 - accuracy: 0.7420
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5285 - accuracy: 0.7424
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5288 - accuracy: 0.7418
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5289 - accuracy: 0.7425
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5284 - accuracy: 0.7413
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5292 - accuracy: 0.7412
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5284 - accuracy: 0.7427
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5285 - accuracy: 0.7424
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5282 - accuracy: 0.7425
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5287 - accuracy: 0.7418

# %%
# Evaluate the model using the test data 
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test,verbose=2)
print(f"Loss; {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5807 - accuracy: 0.7257 - 444ms/epoch - 2ms/step
# Loss; 0.5806674957275391, Accuracy: 0.7257142663002014

# %%
# Export model to HDF5 file
from google.colab import files

nn.save("AlphabetSoupCharity2.h5")
files.download("AlphabetSoupCharity2.h5")

# %% [markdown]
# # Model 1: attempt 3

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=150, input_dim=len(X_train.columns), activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=75, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=50, activation = 'relu'))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=25, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 150)               7500
#
#  dense_5 (Dense)             (None, 75)                11325
#
#  dense_6 (Dense)             (None, 50)                3800
#
#  dense_7 (Dense)             (None, 25)                1275
#
#  dense_8 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 23,926
# Trainable params: 23,926
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5688 - accuracy: 0.7219
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5534 - accuracy: 0.7286
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5502 - accuracy: 0.7301
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7318
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7334
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5459 - accuracy: 0.7329
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5442 - accuracy: 0.7342
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5439 - accuracy: 0.7345
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5429 - accuracy: 0.7356
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5426 - accuracy: 0.7354
# Epoch 11/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5419 - accuracy: 0.7364
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7368
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7360
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5403 - accuracy: 0.7357
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7376
# Epoch 16/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5390 - accuracy: 0.7383
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5390 - accuracy: 0.7388
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7374
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7383
# Epoch 20/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5374 - accuracy: 0.7392
# Epoch 21/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5370 - accuracy: 0.7386
# Epoch 22/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5367 - accuracy: 0.7393
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5366 - accuracy: 0.7391
# Epoch 24/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5361 - accuracy: 0.7403
# Epoch 25/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5360 - accuracy: 0.7397
# Epoch 26/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5356 - accuracy: 0.7392
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7400
# Epoch 28/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5353 - accuracy: 0.7389
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7400
# Epoch 30/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5346 - accuracy: 0.7400
# Epoch 31/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5344 - accuracy: 0.7400
# Epoch 32/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7404
# Epoch 33/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5344 - accuracy: 0.7397
# Epoch 34/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5336 - accuracy: 0.7394
# Epoch 35/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7404
# Epoch 36/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5333 - accuracy: 0.7402
# Epoch 37/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7401
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5334 - accuracy: 0.7412
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5328 - accuracy: 0.7413
# Epoch 40/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7418
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7406
# Epoch 42/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5322 - accuracy: 0.7402
# Epoch 43/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5318 - accuracy: 0.7407
# Epoch 44/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5319 - accuracy: 0.7399
# Epoch 45/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5321 - accuracy: 0.7410
# Epoch 46/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5311 - accuracy: 0.7416
# Epoch 47/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5313 - accuracy: 0.7408
# Epoch 48/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5317 - accuracy: 0.7414
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7412
# Epoch 50/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5315 - accuracy: 0.7410
# Epoch 51/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5313 - accuracy: 0.7409
# Epoch 52/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5304 - accuracy: 0.7423
# Epoch 53/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5301 - accuracy: 0.7416
# Epoch 54/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5305 - accuracy: 0.7413
# Epoch 55/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7411
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5296 - accuracy: 0.7416
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5301 - accuracy: 0.7410
# Epoch 58/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5300 - accuracy: 0.7418
# Epoch 59/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5303 - accuracy: 0.7419
# Epoch 60/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5298 - accuracy: 0.7418
# Epoch 61/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5301 - accuracy: 0.7414
# Epoch 62/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5290 - accuracy: 0.7417
# Epoch 63/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5295 - accuracy: 0.7414
# Epoch 64/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5291 - accuracy: 0.7414
# Epoch 65/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5292 - accuracy: 0.7418
# Epoch 66/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5287 - accuracy: 0.7421
# Epoch 67/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5290 - accuracy: 0.7419
# Epoch 68/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5291 - accuracy: 0.7424
# Epoch 69/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5292 - accuracy: 0.7418
# Epoch 70/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5287 - accuracy: 0.7421
# Epoch 71/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5287 - accuracy: 0.7420
# Epoch 72/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5288 - accuracy: 0.7413
# Epoch 73/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5288 - accuracy: 0.7414
# Epoch 74/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5288 - accuracy: 0.7423
# Epoch 75/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5384 - accuracy: 0.7419
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5299 - accuracy: 0.7419
# Epoch 77/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5281 - accuracy: 0.7428
# Epoch 78/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5287 - accuracy: 0.7422
# Epoch 79/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5284 - accuracy: 0.7425
# Epoch 80/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5281 - accuracy: 0.7420
# Epoch 81/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5282 - accuracy: 0.7426
# Epoch 82/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5283 - accuracy: 0.7423
# Epoch 83/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5286 - accuracy: 0.7418
# Epoch 84/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5282 - accuracy: 0.7422
# Epoch 85/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5281 - accuracy: 0.7423
# Epoch 86/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5294 - accuracy: 0.7421
# Epoch 87/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5281 - accuracy: 0.7419
# Epoch 88/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5284 - accuracy: 0.7414
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5279 - accuracy: 0.7425
# Epoch 90/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5288 - accuracy: 0.7418
# Epoch 91/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5272 - accuracy: 0.7426
# Epoch 92/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5277 - accuracy: 0.7427
# Epoch 93/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5276 - accuracy: 0.7422
# Epoch 94/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5277 - accuracy: 0.7423
# Epoch 95/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5293 - accuracy: 0.7418
# Epoch 96/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5288 - accuracy: 0.7423
# Epoch 97/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5276 - accuracy: 0.7424
# Epoch 98/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5273 - accuracy: 0.7424
# Epoch 99/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5283 - accuracy: 0.7426
# Epoch 100/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5274 - accuracy: 0.7427

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5774 - accuracy: 0.7254 - 445ms/epoch - 2ms/step
# Loss: 0.577391505241394, Accuracy: 0.7253644466400146

# %%
# Export model to HDF5 file
from google.colab import files

nn.save("AlphabetSoupCharity3.h5")
files.download("AlphabetSoupCharity3.h5")

# %% [markdown]
# # Model 1: attempt 4

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=50, input_dim=len(X_train.columns), activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=10, activation = 'relu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 50)                2500
#
#  dense_10 (Dense)            (None, 30)                1530
#
#  dense_11 (Dense)            (None, 10)                310
#
#  dense_12 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 4,351
# Trainable params: 4,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5758 - accuracy: 0.7169
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5532 - accuracy: 0.7294
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7310
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7331
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7314
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5455 - accuracy: 0.7327
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7334
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7342
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7361
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5422 - accuracy: 0.7348
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7362
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7365
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7365
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7364
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7365
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7371
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7367
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7379
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7383
# Epoch 20/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5384 - accuracy: 0.7376
# Epoch 21/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5380 - accuracy: 0.7378
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7386
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5376 - accuracy: 0.7377
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7385
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7392
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7389
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7387
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7392
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7390
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7395
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7402
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7398
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7395
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7393
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7390
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7385
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7394
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7389
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7400
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7391
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7386
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7397
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7401
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7400
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7395
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7401
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7406
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7400
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.7405
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7391
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7393
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7401
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7406
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7404
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7400
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7402
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7410
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7411
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7400
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7400
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7410
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7408
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7403
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7411
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7408
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7409
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7411
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7404
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7404
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7412
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7409
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7409
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7404
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7403
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7405
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7399
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7411
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7405
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7409
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7400
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7406
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7402
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7412
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7404
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7409
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7406
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7399
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7412
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7403
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7409
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7400
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7416
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7411
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7409
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7410
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7409
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7411
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5307 - accuracy: 0.7407
# Epoch 99/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5309 - accuracy: 0.7405
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7413

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5695 - accuracy: 0.7263 - 447ms/epoch - 2ms/step
# Loss: 0.5694979429244995, Accuracy: 0.7262973785400391

# %%
# Export model to HDF5 file
from google.colab import files

nn.save("AlphabetSoupCharity4.h5")
files.download("AlphabetSoupCharity4.h5")
